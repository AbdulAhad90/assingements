# %%
with open("Names.txt", 'r') as f:
    text_of_file = f.read()

# %%
print(text_of_file)
# Out:
# GEORGE MCINTOSH
# JOHN	ARCHER
# MARKEETA	KLINEFELTER
# JUDITH	BEAL
# ROBERTO	REYES
# JOANNE	KELDERMAN
# FLEETA	ARTHUR
# SHARON	JACOBS
# LELA	FARMER
# CATHERINE	EVANS
# COURTNEY	CAIN
# MARCIA	SEIFRIG
# SARAH	MORRIS
# MARY	AMOS
# JERRY	COURTS
# REVEL	MASSIE
# GLORIA	WISEMAN
# EDNA	MCFALL
# DOREEN	HARMON
# JAMES	HOWARD
# DAVID	BOOE
# SUSAN	PROUGH
# STEVE	MILLER
# VICTORIANO	RAMIREZ
# ANDREW	COSENTINO
# BRENDA	SALLEE
# SYLVIA	SCROGGINS
# JO	DOYLE
# VICKY	MATTHIAS
# CRAIG	SAPONKA
# ROBERT	JERINA
# MELISSA	STUTSMAN
# STEVEN	KROUSE
# MIKE	FRAZEE
# JULIAN	CHASTAIN
# MARVIN	VAN
# VICKI	BELL
# JANE	LENTINE
# APRIL	SCHWARTZ
# CHERYL	WASHINGTON
# JOHNNIE	STANSON
# LINDA	DONNELLY
# CLARA	HOLMES
# CAROLYN	KETCHEM
# POLLY	SHULL
# THERESA	HANDSHOE
# CONSTANCE	KRESS
# NORA	CASSIDY
# ANN	HARGETT
# WILLIAM	THOMASON
# LORI	HELTON
# ALBERTA	BEAVER
# K	ROGERS
# DELORES	RAGENS
# JEANETTE	KACZMAREK
# BARBARA	NAVE
# JON	CROWE
# DAPHNE	ROSS
# LYNN	HAYES
# CATHY	ALLEN
# ED	NEWTON
# KIM	CASE
# PATRICIA	BUNNER
# ...

# %%
list()
# Out:
# []

# %%
listt = text_of_file.split()

# %%
print(listt)
# Out:
# ['GEORGE', 'MCINTOSH', 'JOHN', 'ARCHER', 'MARKEETA', 'KLINEFELTER', 'JUDITH', 'BEAL', 'ROBERTO', 'REYES', 'JOANNE', 'KELDERMAN', 'FLEETA', 'ARTHUR', 'SHARON', 'JACOBS', 'LELA', 'FARMER', 'CATHERINE', 'EVANS', 'COURTNEY', 'CAIN', 'MARCIA', 'SEIFRIG', 'SARAH', 'MORRIS', 'MARY', 'AMOS', 'JERRY', 'COURTS', 'REVEL', 'MASSIE', 'GLORIA', 'WISEMAN', 'EDNA', 'MCFALL', 'DOREEN', 'HARMON', 'JAMES', 'HOWARD', 'DAVID', 'BOOE', 'SUSAN', 'PROUGH', 'STEVE', 'MILLER', 'VICTORIANO', 'RAMIREZ', 'ANDREW', 'COSENTINO', 'BRENDA', 'SALLEE', 'SYLVIA', 'SCROGGINS', 'JO', 'DOYLE', 'VICKY', 'MATTHIAS', 'CRAIG', 'SAPONKA', 'ROBERT', 'JERINA', 'MELISSA', 'STUTSMAN', 'STEVEN', 'KROUSE', 'MIKE', 'FRAZEE', 'JULIAN', 'CHASTAIN', 'MARVIN', 'VAN', 'VICKI', 'BELL', 'JANE', 'LENTINE', 'APRIL', 'SCHWARTZ', 'CHERYL', 'WASHINGTON', 'JOHNNIE', 'STANSON', 'LINDA', 'DONNELLY', 'CLARA', 'HOLMES', 'CAROLYN', 'KETCHEM', 'POLLY', 'SHULL', 'THERESA', 'HANDSHOE', 'CONSTANCE', 'KRESS', 'NORA', 'CASSIDY', 'ANN', 'HARGETT', 'WILLIAM',
